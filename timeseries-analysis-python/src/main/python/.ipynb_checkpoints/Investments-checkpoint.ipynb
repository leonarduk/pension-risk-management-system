# %% [markdown]
# # Investment summary

# %% [markdown]
# This sheet should keep track of my investments

# %%
import pandas as pd
from datacollection.TimeSeriesAPI import getTimeSeriesWithIncremementingKey as getDataFrame

# %%
symbol="CTY.L"
years=10
data = getDataFrame(symbol, years )
data
# Out:
# http://localhost:8091/stock/download/ticker/CTY.L?years=10&interpolate=true&clean=true 20880
#         ID      date   open    high     low  close    volume  \
# 0        1  20111207  287.5  287.80  280.89  281.9  159684.0
# 1        2  20111208  285.6  285.60  279.90  283.0  459137.0
# 2        3  20111209  280.0  283.20  278.40  282.1  197965.0
# 3        4  20111212  279.4  282.74  277.10  281.9  151882.0
# 4        5  20111213  277.9  281.50  276.60  277.5  174082.0
# ...    ...       ...    ...     ...     ...    ...       ...
# 2605  2606  20211201  385.0  386.50  383.50  385.0  928903.0
# 2606  2607  20211202  381.0  385.50  380.00  385.0  943031.0
# 2607  2608  20211203  388.0  388.00  384.50  386.0  718260.0
# 2608  2609  20211206  389.0  392.00  387.00  392.0  734270.0
# 2609  2610  20211207  391.0  397.00  391.00  395.0  626792.0
#
#                                                 comment
# 0                                          Alphavantage
# ...

# %%
pd.read_csv("C:/Users/steph/Downloads/Security_Performance_(Standard).csv")
# Out:
#                                                  Name        Symbol  \
# 0                                     AstraZeneca PLC         AZN.L
# 1                               Capital Gearing Trust         CGT.L
# 2                                          Diageo plc         DGE.L
# 3                                        Experian plc        EXPN.L
# 4                                 GlaxoSmithKline plc         GSK.L
# 5                                          Greggs plc         GRG.L
# 6                                 Imperial Brands PLC         IMB.L
# 7   iShares Global Inflation Linked Government Bon...        GILG.L
# 8                    iShares Gold Producers UCITS ETF          SPGP
# 9   iShares plc MSCI Europe ex-UK GBP Hedged UCITS...        EUXS.L
# 10         iShares S&P 500 GBP Hedged UCITS ETF (Acc)        IGUS.L
# 11  iShares £ Corp Bond ex-Financials UCITS ETF GB...        ISXF.L
# 12                    JPMorgan Russian Securities Plc         JRS.L
# ...

# %%
pd.read_csv("C:/Users/steph/Downloads/Securities_(InestrumentTable).csv")
# Out:
#                                                  Name  \
# 0                                     AstraZeneca PLC
# 1                               Capital Gearing Trust
# 2                                          Diageo plc
# 3                                        Experian plc
# 4                                 GlaxoSmithKline plc
# 5                                          Greggs plc
# 6                                 Imperial Brands PLC
# 7   iShares Global Inflation Linked Government Bon...
# 8                    iShares Gold Producers UCITS ETF
# 9   iShares plc MSCI Europe ex-UK GBP Hedged UCITS...
# 10         iShares S&P 500 GBP Hedged UCITS ETF (Acc)
# 11  iShares £ Corp Bond ex-Financials UCITS ETF GB...
# 12                    JPMorgan Russian Securities Plc
# 13                          Legal & General Group Plc
# 14     M&G Global Government Bond Fund Sterling I Acc
# 15             M&G Optimal Income Fund Sterling I Inc
# ...
